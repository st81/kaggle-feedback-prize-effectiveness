# %%
from pathlib import Path

import pandas as pd


feedback_2021_dir = "../input/feedback-prize-2021"
feedback_effectiveness_dir = "../input/feedback-prize-effectiveness/"

# %%
train_df = pd.read_csv(Path(feedback_2021_dir) / "train.csv")
train_df
# Out:
#                   id  discourse_id  discourse_start  discourse_end  \
# 0       423A1CA112E2  1.622628e+12              8.0          229.0
# 1       423A1CA112E2  1.622628e+12            230.0          312.0
# 2       423A1CA112E2  1.622628e+12            313.0          401.0
# 3       423A1CA112E2  1.622628e+12            402.0          758.0
# 4       423A1CA112E2  1.622628e+12            759.0          886.0
# ...              ...           ...              ...            ...
# 144288  4C471936CD75  1.618153e+12           2234.0         3203.0
# 144289  4C471936CD75  1.618153e+12           3221.0         4509.0
# 144290  4C471936CD75  1.618025e+12           4510.0         4570.0
# 144291  4C471936CD75  1.618025e+12           4570.0         4922.0
# 144292  4C471936CD75  1.618025e+12           4935.0         5825.0
#
#                                            discourse_text  \
# 0       Modern humans today are always on their phone....
# ...

# %%
train_txt_dir = Path(feedback_2021_dir) / "train"
for filename in train_txt_dir.glob("*.txt"):
    print(filename)
    with open(filename, "r") as f:
        texts = f.read()
        print(texts)
    break
# Out:
# ../input/feedback-prize-2021/train/1FBC2049262E.txt
# All around the world different countries have been noticing some things in life that are just better without cars or atleast less cars. With less cars things are more calming; its also better for everyone, including the enviroment.
#
# ...

# %%
train_df[train_df["id"] == filename.stem]
# Out:
#                 id  discourse_id  discourse_start  discourse_end  \
# 7465  1FBC2049262E  1.622233e+12              0.0          135.0
# 7466  1FBC2049262E  1.622234e+12            136.0          175.0
# 7467  1FBC2049262E  1.622234e+12            176.0          231.0
# 7468  1FBC2049262E  1.622234e+12            248.0          299.0
# 7469  1FBC2049262E  1.622234e+12            300.0         1034.0
# 7470  1FBC2049262E  1.622234e+12           1086.0         1131.0
# 7471  1FBC2049262E  1.622234e+12           1132.0         1933.0
# 7472  1FBC2049262E  1.622234e+12           1950.0         2079.0
#
#                                          discourse_text        discourse_type  \
# 7465  All around the world different countries have ...              Position
# 7466            With less cars things are more calming                  Claim
# 7467  its also better for everyone, including the en...                 Claim
# ...

# %%
train_df = pd.read_csv(Path(feedback_effectiveness_dir) / "train.csv")
train_df
# Out:
#        discourse_id      essay_id  \
# 0      0013cc385424  007ACE74B050
# 1      9704a709b505  007ACE74B050
# 2      c22adee811b6  007ACE74B050
# 3      a10d361e54e4  007ACE74B050
# 4      db3e453ec4e2  007ACE74B050
# ...             ...           ...
# 36760  9f63b687e76a  FFA381E58FC6
# 36761  9d5bd7d86212  FFA381E58FC6
# 36762  f1b78becd573  FFA381E58FC6
# 36763  cc184624ca8e  FFA381E58FC6
# 36764  c8a973681feb  FFA381E58FC6
#
#                                           discourse_text  \
# 0      Hi, i'm Isaac, i'm going to be writing about h...
# 1      On my perspective, I think that the face is a ...
# 2      I think that the face is a natural landform be...
# 3      If life was on Mars, we would know by now. The...
# 4      People thought that the face was formed by ali...
# ...                                                  ...
# 36760  For many people they don't like only asking on...
# 36761  also people have different views and opinions ...
# ...
